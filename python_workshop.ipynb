# %% [markdown]
# <a href="https://colab.research.google.com/github/cnuphy444-web/Srinivas_Python-workshop/blob/main/python_workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day-1

# %%
import keyword
print("standrd keyword=",len(keyword.kwlist))
print("soft keyword=",keyword.softkwlist)
print("all keyword=",keyword.kwlist)
# Out:
# standrd keyword= 35
# soft keyword= ['_', 'case', 'match', 'type']
# all keyword= ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
x=5
y="python"
z=3.5
print(x)
print(y)
print(z)
# Out:
# 5
# python
# 3.5

# %% [markdown]
# Casting

# %%
y1=2
print(y1)
print(type(y1))

y2=float(y1)
print(y2)
print(type(y2))

y3=str(y1)
print(y3)
print(type(y3))
# Out:
# 2
# <class 'int'>
# 2.0
# <class 'float'>
# 2
# <class 'str'>

# %% [markdown]
# Python-Variable Names

# %%
myname="srinivas"
my_dep="BS"
my_university="sr university"
myloc="warangal"
Myloc="telangana"
mycountry="India"

print(myname)
print(my_dep)
print(my_university)
print(myloc)
print(Myloc)
print(mycountry)
# Out:
# srinivas
# BS
# sr university
# warangal
# telangana
# India

# %%
a=input("enter first name")
b=input("enter last name")
print("=======")
print("airthmatic operation on string")
print("=======")
full_name=a+b #string concatenation
print("full name=",full_name)
repeat_name=full_name*2
print("repeat name=",repeat_name)
print("========")
# Out:
# enter first namesrinivas
# enter last namepattipaka
# =======
# airthmatic operation on string
# =======
# full name= srinivaspattipaka
# repeat name= srinivaspattipakasrinivaspattipaka
# ========

# %%
a=input("enter first name")
b=input("enter last name")
print("=======")
print("airthmatic operation on string")
print("=======")
full_name=a+b #string concatenation
print("full name=",full_name)
repeat_name=full_name*2
print("repeat name=",repeat_name)
print("========")
# Out:
# enter first namesrinivas
# enter last namepattipaka
# =======
# airthmatic operation on string
# =======
# full name= srinivaspattipaka
# repeat name= srinivaspattipakasrinivaspattipaka
# ========

# %% [markdown]
# Precedence Operators

# %%
a=20
b=30
c=40
print("value1=",a+b*c)
print("value2=",(a+b)*c)
print("value3=",c/a+(b*2))
# Out:
# value1= 1220
# value2= 2000
# value3= 62.0

# %%
num1=10
num2=0
num3=10
str1="Good"
str2="Afternoon"
print("Status",num1==num2)
print("Status=",num1==num3)
print("Status=",num1!=num2)
print("Status=",num1!=num3)
print("Status=",num1>num2)
print("Status=",num1<num2)
print("Status=",num1>=num2)
print("Status=",num1<=num3)
# Out:
# Status False
# Status= True
# Status= True
# Status= False
# Status= True
# Status= False
# Status= True
# Status= True

# %%
num1=10
num2=0
num3=10
print("Status=",num1==num2 and num1==num3)
print("Status=",num1==num2 or num1==num3)
print("Status=",not(num1>=num3))
# Out:
# Status= False
# Status= True
# Status= False

# %% [markdown]
# Assignment operator

# %%
num1=10
print("num1=",num1)
num2=num1
print("num2=",num2)
num=20
print("num2=",num2)
num1+num2 # num1=10+20
print("num1=",num1)
num1=num2 # num1=30-20

# %% [markdown]
# Membership Operator

# %%
students=["hayaan","vihaan"]
call_attendance=input("call student name")
print("status=",call_attendance in students)
print("status=",call_attendance not in students)
# Out:
# call student namehayaan
# status= True
# status= False

# %%
students=["hayaan","vihaan"]
call_attendance=input("call student name")
print("status=",call_attendance in students)
print("status=",call_attendance not in students)
# Out:
# call student namesrinivas
# status= False
# status= True

# %% [markdown]
# Bitwise Operator

# %%
a=10 #a=1010
b=5 #b=0101
print("Result=",a&b)
print("Result=",a|b)
print("Result=",~a)
print("Result=",~b)
print("Result=",a^b)
# Out:
# Result= 0
# Result= 15
# Result= -11
# Result= -6
# Result= 15

# %% [markdown]
# Identity operator

# %%
a=[1,2,3]
b=a
c=[1,2,3]
print("status=",a is b)
print("status=",a is c)
print("status=",a is not c)
# Out:
# status= True
# status= False
# status= True

# %% [markdown]
# Decision Making

# %%
userid=["srinivas","Harisri@444"]
username=input("input user name")
if(username in userid):
    print("user exist")
else:
    print("user not exist")
# Out:
# input user namesrinivas
# user exist

# %% [markdown]
# #odd number chec (If statement)

# %%
num=input("enter number to check")
num=int(num)
if(num%2==0):
    print(f"number {num} is even")
else:
    print(f"number {num} is odd")
# Out:
# enter number to check2
# number 2 is even

# %%
num=input("enter number to check")
num=int(num)
if(num%2==0):
    print(f"number {num} is even")
else:
    print(f"number {num} is odd")
# Out:
# enter number to check3
# number 3 is odd

# %% [markdown]
# Nested if statement

# %%
marks=input("enter student marks")
marks=int(marks)
if marks>45:
  print("student pass in subject grade")
  if marks>60:
    print("student in D grade")
# Out:
# enter student marks75
# student pass in subject grade
# student in D grade

# %%
marks=input("enter student marks")
marks=int(marks)

if marks > 90:
    print("student in O grade")
if marks > 60:
    print("student in D grade")
if marks >= 45:
    print("student pass in subject grade")
else:
    print("student fail in subject grade")
# Out:
# enter student marks61
# student in D grade
# student pass in subject grade
