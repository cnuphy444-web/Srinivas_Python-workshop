# %% [markdown]
# <a href="https://colab.research.google.com/github/cnuphy444-web/Srinivas_Python-workshop/blob/main/python_workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day-1

# %%
import keyword
print("standrd keyword=",len(keyword.kwlist))
print("soft keyword=",keyword.softkwlist)
print("all keyword=",keyword.kwlist)
# Out:
# standrd keyword= 35
# soft keyword= ['_', 'case', 'match', 'type']
# all keyword= ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
x=5
y="python"
z=3.5
print(x)
print(y)
print(z)
# Out:
# 5
# python
# 3.5

# %% [markdown]
# Casting

# %%
y1=2
print(y1)
print(type(y1))

y2=float(y1)
print(y2)
print(type(y2))

y3=str(y1)
print(y3)
print(type(y3))
# Out:
# 2
# <class 'int'>
# 2.0
# <class 'float'>
# 2
# <class 'str'>

# %% [markdown]
# Python-Variable Names

# %%
myname="srinivas"
my_dep="BS"
my_university="sr university"
myloc="warangal"
Myloc="telangana"
mycountry="India"

print(myname)
print(my_dep)
print(my_university)
print(myloc)
print(Myloc)
print(mycountry)
# Out:
# srinivas
# BS
# sr university
# warangal
# telangana
# India

# %%
a=input("enter value of a")
b=input("enter value of b")
a=int(a)
b=int(b)
print("=======")
print("sample calculator")
print("=======")
print("addition=",a+b)
print("mul=",a*b)
print("====")
# Out:
# enter value of asrinivas
# enter value of bpattipaka
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_458/2202064099.py in <cell line: 0>()
#       1 a=input("enter value of a")
#       2 b=input("enter value of b")
# ----> 3 a=int(a)
#       4 b=int(b)
#       5 print("=======")
#
# ValueError: invalid literal for int() with base 10: 'srinivas'

# %%
a=input("enter first name")
b=input("enter last name")
print("=======")
print("airthmatic operation on string")
print("=======")
full_name=a+b #string concatenation
print("full name=",full_name)
repeat_name=full_name*2
print("repeat name=",repeat_name)
print("========")
# Out:
# enter first namesrinivas
# enter last namepattipaka
# =======
# airthmatic operation on string
# =======
# full name= srinivaspattipaka
# repeat name= srinivaspattipakasrinivaspattipaka
# ========

# %%
a=input("enter first name")
b=input("enter last name")
print("=======")
print("airthmatic operation on string")
print("=======")
full_name=a+b #string concatenation
print("full name=",full_name)
repeat_name=full_name*2
print("repeat name=",repeat_name)
print("========")
# Out:
# enter first namesrinivas
# enter last namepattipaka
# =======
# airthmatic operation on string
# =======
# full name= srinivaspattipaka
# repeat name= srinivaspattipakasrinivaspattipaka
# ========

# %% [markdown]
# Precedence Operators

# %%
a=20
b=30
c=40
print("value1=",a+b*c)
print("value2=",(a+b)*c)
print("value3=",c/a+(b*2))
# Out:
# value1= 1220
# value2= 2000
# value3= 62.0

# %%
num1=10
num2=0
num3=10
str1="Good"
str2="Afternoon"
print("Status",num1==num2)
print("Status=",num1==num3)
print("Status=",num1!=num2)
print("Status=",num1!=num3)
print("Status=",num1>num2)
print("Status=",num1<num2)
print("Status=",num1>=num2)
print("Status=",num1<=num3)
# Out:
# Status False
# Status= True
# Status= True
# Status= False
# Status= True
# Status= False
# Status= True
# Status= True
